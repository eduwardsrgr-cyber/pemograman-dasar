# %% [markdown]
# <a href="https://colab.research.google.com/github/eduwardsrgr-cyber/pemograman-dasar/blob/main/pertemuan_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#biodata saya
nama="eduward siregar"
umur="21"
jurusan="RPE"
semester= 3
matakuliah="Pemograman Dasar"
status_lulus=False


print(nama)
print(umur)
print(semester)
print(jurusan)
print(matakuliah)
print(status_lulus)
# Out:
# eduward siregar
# 21
# 3
# RPE
# Pemograman Dasar
# False
